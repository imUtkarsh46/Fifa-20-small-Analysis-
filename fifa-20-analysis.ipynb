# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('../input/fifa-20-complete-player-dataset/players_20.csv')

# %%
fifa.head()

# %%
fifa.shape

# %%
for Cname in fifa.columns:
    print(Cname)

# %%
fifa['nationality'].value_counts()[:10]

# %%
plt.figure(figsize = (8,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]), color='g')
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]

# %%
player_salary.head()

# %%
player_salary = player_salary.sort_values(['wage_eur'], ascending=False)

# %%
player_salary.head()

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'][0:5]),list(player_salary['wage_eur'][0:5]), color='r')
plt.show()

# %%
germany = fifa[fifa['nationality'] == 'Germany']
germany.head(10)

# %%
germany.sort_values(['height_cm'], ascending=False).head()

# %%
germany.sort_values(['weight_kg'], ascending=False).head()

# %%
germany.sort_values(['wage_eur'], ascending=False).head()

# %%
germany[['short_name', 'wage_eur']].sort_values(['wage_eur'], ascending=False)

# %%
player_shooting = fifa[['short_name', 'shooting']]

# %%
player_shooting.sort_values(['shooting'], ascending=False)

# %%
player_shooting = player_shooting.sort_values(['shooting'], ascending=False)

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_shooting['short_name'][0:5]), list(player_shooting['shooting'][0:5]), color='y')
plt.show()

# %%
player_defending = fifa[['short_name', 'defending', 'nationality', 'club']]

# %%
player_defending.sort_values(['defending'], ascending=False)

# %%
real_madrid = fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(['wage_eur'], ascending=False).head()

# %%
real_madrid.sort_values(['shooting'], ascending=False).head()

# %%
real_madrid.sort_values(['defending'], ascending=False).head()

# %%
real_madrid['nationality'].value_counts()
